# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import pickle
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import tqc
import pylab as plt
from importlib import reload

import torch

# %%
env_name = "Pendulum-v1"
#env_name = "LunarLander-v2"
log_interval = 20         # print avg reward in the interval
max_episodes = 300 # max training episodes
max_timesteps = 2000         # max timesteps in one episode
save_interval = 300
train_iter = 32      # update networks for given batched after every episode
random_seed = 42

# %%
def save_statistics(rewards,lengths,q_losses,pi_losses,temperature_loss,env_name,random_seed,episode):
    with open(f"./results/SAC_{env_name}-s{random_seed}-e{episode}-stat.pkl", 'wb') as f:
        pickle.dump({"rewards" : rewards, "lengths": lengths, "train": train_iter,
                        "pi_losses": pi_losses, "q_losses": q_losses,
                        "temperature_loss":temperature_loss}, f)

# %%
def run_sac_agent_in_environment(env_name=env_name,log_interval=log_interval,save_interval=save_interval,max_episodes=max_episodes,max_timesteps=max_timesteps,train_iter=train_iter,random_seed=random_seed):
    torch.manual_seed(random_seed)
    np.random.seed(random_seed)

    env = gym.make(env_name)

    if env_name == "LunarLander-v2":
        env = gym.make(env_name,continuous=True)
    else:
        env = gym.make(env_name)
    agent = tqc.TQC_Agent(env.observation_space, env.action_space)
    rewards = []
    lengths = []
    q_losses = []
    policy_losses = []
    temperature_losses = []
    timestep = 0

    for episode in range(1,max_episodes+1):
        ob, _info = env.reset()
        total_reward=0
        for t in range(max_timesteps):
            timestep +=1
            done = False
            a = agent.act(ob)
            (ob_new,reward,done,trunc,_info) = env.step(a)
            total_reward += reward
            done_val = int(done)
            
            agent.store_transition((ob,a,reward,ob_new,done_val))
            ob=ob_new
            if bool(done) or trunc: break

        q_loss,pi_loss,temperature_loss = agent.train(train_iter)
            
        q_losses.extend(q_loss)
        policy_losses.extend(pi_loss)
        temperature_losses.extend(temperature_loss)
        rewards.append(total_reward)
        lengths.append(t)

        if episode % save_interval ==0:
            print("########### Save checkpoint ################")
            torch.save(agent.get_networks_states(),f'./results/SAC_{env_name}-e{episode}-t{train_iter}-s{random_seed}.pth')
            save_statistics(rewards,lengths,q_losses,policy_losses,temperature_losses,env_name,random_seed,episode)

        if episode % log_interval == 0:
            avg_reward = np.mean(rewards[-log_interval:])
            avg_length = int(np.mean(lengths[-log_interval:]))
            print('Episode {} \t avg length: {} \t reward: {}'.format(episode, avg_length, avg_reward))
    save_statistics(rewards,lengths,q_losses,policy_losses,temperature_losses,env_name,random_seed,episode)

# %%
run_sac_agent_in_environment(env_name=env_name,log_interval=log_interval,save_interval=save_interval,max_episodes=max_episodes,max_timesteps=max_timesteps,train_iter=train_iter,random_seed=random_seed)
# Out:
# Episode 20 	 avg length: 199 	 reward: -1322.6573363149605
# Episode 40 	 avg length: 199 	 reward: -1159.507930599017
# Episode 60 	 avg length: 199 	 reward: -1274.4540616652591
# Episode 80 	 avg length: 199 	 reward: -1298.7159456255486
# Episode 100 	 avg length: 199 	 reward: -1145.0276771340061
# Episode 120 	 avg length: 199 	 reward: -1342.394325803017
# Episode 140 	 avg length: 199 	 reward: -1244.4257154089773
# Episode 160 	 avg length: 199 	 reward: -1178.6341749832868
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 run_sac_agent_in_environment(env_name=env_name,log_interval=log_interval,save_interval=save_interval,max_episodes=max_episodes,max_timesteps=max_timesteps,train_iter=train_iter,random_seed=random_seed)
#
# Cell In[4], line 34, in run_sac_agent_in_environment(env_name, log_interval, save_interval, max_episodes, max_timesteps, train_iter, random_seed)
#      31     ob=ob_new
#      32     if bool(done) or trunc: break
# ---> 34 q_loss,pi_loss,temperature_loss = agent.train(train_iter)
#      36 q_losses.extend(q_loss)
#      37 policy_losses.extend(pi_loss)
#
# File c:\Users\Moritz Christ\Documents\Uni\23Wintersemester\RL\Project\RL\RL_Agent\TQC\tqc.py:215, in TQC_Agent.train(self, iter_fit)
#     213 if self.train_iter % self._config["frequency_update_Q"] == 0:
#     214     q_loss = self.calculate_critic_loss(s0,a,rew,done,s1)
# --> 215     q_loss = self.update_q_nets(q_loss)
#     216     q_losses.append(q_loss)
#     218 #update policy and Update temperature
#
# File c:\Users\Moritz Christ\Documents\Uni\23Wintersemester\RL\Project\RL\RL_Agent\TQC\tqc.py:175, in TQC_Agent.update_q_nets(self, q_loss)
#     172 def update_q_nets(self,q_loss):
#     173     #update critics
#     174     self.critic.optimizer.zero_grad()
# --> 175     q_loss.backward()
#     176     self.critic.optimizer.step()
#     177     return q_loss.item()
#
# File d:\Conda\envs\rl\lib\site-packages\torch\_tensor.py:487, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     477 if has_torch_function_unary(self):
#     478     return handle_torch_function(
#     479         Tensor.backward,
#     480         (self,),
#    (...)
#     485         inputs=inputs,
#     486     )
# --> 487 torch.autograd.backward(
#     488     self, gradient, retain_graph, create_graph, inputs=inputs
#     489 )
#
# File d:\Conda\envs\rl\lib\site-packages\torch\autograd\__init__.py:200, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     195     retain_graph = create_graph
#     197 # The reason we repeat same the comment below is that
#     198 # some Python versions print out the first line of a multi-line function
#     199 # calls in the traceback and some print out the last line
# --> 200 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     201     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     202     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Helper Functions

# %%
def running_mean(x, N):
    cumsum = np.cumsum(np.insert(x, 0, 0)) 
    return (cumsum[N:] - cumsum[:-N]) / float(N)

# %%
def run(env, agent:tqc.TQC_Agent, n_episodes=100):
    rewards = []
    observations = []
    actions = []
    agent.eval
    for ep in range(1, n_episodes+1):
        ep_reward = 0
        state, _info = env.reset()
        for t in range(2000):
            action = agent.act(state)
            state, reward, done, _trunc, _info = env.step(action)
            observations.append(state)
            actions.append(action)
            ep_reward += reward
            if done or _trunc:
                break
        rewards.append(ep_reward)
        ep_reward = 0
    print(f'Mean reward: {np.mean(rewards)}')
    observations = np.asarray(observations)
    actions = np.asarray(actions)
    return observations, actions, rewards
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 def run(env, agent:TQC_Agent, n_episodes=100):
#       2     rewards = []
#       3     observations = []
#
# NameError: name 'TQC_Agent' is not defined

# %% [markdown]
# # SAC

# %%
with open(f"./results/SAC_{env_name}-s{random_seed}-e{max_episodes}-stat.pkl", 'rb') as f:
    data = pickle.load(f)
    rewards = np.asarray(data["rewards"])
    q_losses =  np.asarray(data["q_losses"])
    pi_losses  = np.asarray(data["pi_losses"])
    temperature_losses = np.asarray(data["temperature_loss"])

# %%
fig=plt.figure(figsize=(6,3.8))
plt.plot(running_mean(q_losses,10),label=f"Q loss")
plt.plot(running_mean(pi_losses,10),label=f"Pi loss")
#plt.plot(running_mean(temperature_losses,10),label=f"Temp loss")
plt.legend()

# %%
fig=plt.figure(figsize=(6,3.8))
plt.plot(running_mean(rewards,10),label=f"rewards")
plt.legend()

# %% [markdown]
# ## value function

# %%
def plot_Q_function(q_function, observations, actions, plot_dim1=0, plot_dim2=2,
                    label_dim1="cos(angle)", label_dim2="angular velocity"):
    plt.rcParams.update({'font.size': 12})
    observations_tensor = torch.from_numpy(observations)
    actions_tensor = torch.from_numpy(actions)
    values =q_function.get_min_Q_value(observations_tensor,actions_tensor).detach().numpy()
    
    fig = plt.figure(figsize=[10,8])
    ax = fig.add_subplot()
    surf = ax.scatter (observations[:,plot_dim1], observations[:,plot_dim2],  c = values, cmap=cm.coolwarm)
    ax.set_xlabel(label_dim1)
    ax.set_ylabel(label_dim2)

    return fig

# %%
env = gym.make(env_name)

# %%
checkpoint = f"./SAC_{env_name}-e{int(max_episodes/save_interval)*save_interval}-t{train_iter}-s{random_seed}.pth"
print(checkpoint)
# Out:
# ./SAC_Pendulum-v1-e2000-t32-s42.pth

# %%
agent  = sac.SAC_Agent(env.observation_space, env.action_space)
#print(torch.load(checkpoint)[1])
agent.load_network_states(torch.load(checkpoint))
agent.eval()
# Out:
# Agent now in evaluation Mode

# %%
observations, actions, rewards = run(env,agent,100)
# Out:
# Mean reward: -146.21621540986212

# %%
_ = plot_Q_function(agent.critic,observations,actions)

# %%
env = gym.make(env_name, render_mode="human")
agent = sac.SAC_Agent(env.observation_space, env.action_space)
agent.load_network_states(torch.load(checkpoint))
agent.eval()
#TODO implement agent working in environment
observation, info = env.reset(seed=42)
for _ in range(500):
   action = agent.act(observation)
   observation, reward, terminated, truncated, info = env.step(action)

   if terminated or truncated:
      observation, info = env.reset()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 env = gym.make(env_name, render_mode="human")
# ----> 2 agent = sac.SAC_Agent(env.observation_space, env.action_space)
#       3 agent.load_network_states(torch.load(checkpoint))
#       4 agent.eval()
#
# NameError: name 'sac' is not defined

# %%
env.close()

# %% [markdown]
# ## HalfCheetah

# %%
env_name = "HalfCheetah-v4"
log_interval = 20         # print avg reward in the interval
max_episodes = 3000 # max training episodes
max_timesteps = 2000         # max timesteps in one episode
save_interval = 500
train_iter = 32      # update networks for given batched after every episode
random_seed = 42

# %%
run_sac_agent_in_environment(env_name=env_name,log_interval=log_interval,save_interval=save_interval,max_episodes=max_episodes,max_timesteps=max_timesteps,train_iter=train_iter,random_seed=random_seed)
# Out:
# Episode 20 	 avg length: 999 	 reward: -261.87925713882265
# Episode 40 	 avg length: 999 	 reward: -309.93763418729316
# Episode 60 	 avg length: 999 	 reward: -306.5203043502164
# Episode 80 	 avg length: 999 	 reward: -325.52845311482776
# Episode 100 	 avg length: 999 	 reward: -304.3582593108234
# Episode 120 	 avg length: 999 	 reward: -300.3600459461605
# Episode 140 	 avg length: 999 	 reward: -324.84450288225884
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 run_sac_agent_in_environment(env_name=env_name,log_interval=log_interval,save_interval=save_interval,max_episodes=max_episodes,max_timesteps=max_timesteps,train_iter=train_iter,random_seed=random_seed)
#
# Cell In[4], line 34, in run_sac_agent_in_environment(env_name, log_interval, save_interval, max_episodes, max_timesteps, train_iter, random_seed)
#      31     ob=ob_new
#      32     if bool(done) or trunc: break
# ---> 34 q_loss,pi_loss,temperature_loss = agent.train(train_iter)
#      36 q_losses.extend(q_loss)
#      37 policy_losses.extend(pi_loss)
#
# File c:\Users\Moritz Christ\Documents\Uni\23Wintersemester\RL\Project\RL\RL_Agent\TQC\tqc.py:202, in TQC_Agent.train(self, iter_fit)
#     197 ######Start SAC train loop#######
#     198
#     199 #Calculate losses
#     200 #updateQ
#     201 if self.train_iter % self._config["frequency_update_Q"] == 0:
# --> 202     q_loss = self.calculate_critic_loss(s0,a,rew,done,s1)
#     204 #update policy and Update temperature
#     205 if self.train_iter % self._config["frequency_update_actor"] == 0:
#
# File c:\Users\Moritz Christ\Documents\Uni\23Wintersemester\RL\Project\RL\RL_Agent\TQC\tqc.py:135, in TQC_Agent.calculate_critic_loss(self, s0, action, rew, done, s1)
#     132     # this is the td
#     133     y = (rew + self.discount * (1 - done)*target_value)
# --> 135 z = self.critic.forward(s0,action)
#     136 q_loss = quantile_huber_loss(z,y)
#     137 return q_loss
#
# File c:\Users\Moritz Christ\Documents\Uni\23Wintersemester\RL\Project\RL\RL_Agent\TQC\Critic.py:35, in Critic_Quantiles.forward(self, state, action)
#      32 def forward(self,state,action):
#      33     # batch,nets,quantiles
#      34     input = torch.cat([state,action],dim=1)
# ---> 35     quantiles = torch.stack(tuple(net.forward(input) for net in self.networks),dim=1)
#      36     return quantiles
#
# File c:\Users\Moritz Christ\Documents\Uni\23Wintersemester\RL\Project\RL\RL_Agent\TQC\Critic.py:35, in <genexpr>(.0)
#      32 def forward(self,state,action):
#      33     # batch,nets,quantiles
#      34     input = torch.cat([state,action],dim=1)
# ---> 35     quantiles = torch.stack(tuple(net.forward(input) for net in self.networks),dim=1)
#      36     return quantiles
#
# File c:\Users\Moritz Christ\Documents\Uni\23Wintersemester\RL\Project\RL\RL_Agent\TQC\Basic\feedforward.py:25, in Feedforward.forward(self, x)
#      23 def forward(self, x):
#      24     for layer,activation_fun in zip(self.layers, self.activations):
# ---> 25         x = activation_fun(layer(x))
#      26     if self.output_activation is not None:
#      27         return self.output_activation(self.readout(x))
#
# File d:\Conda\envs\rl\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File d:\Conda\envs\rl\lib\site-packages\torch\nn\modules\linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
with open(f"./results/SAC_{env_name}-s{random_seed}-e{int(max_episodes/save_interval)*save_interval}-stat.pkl", 'rb') as f:
    data = pickle.load(f)
    rewards = np.asarray(data["rewards"])
    q_losses =  np.asarray(data["q_losses"])
    pi_losses  = np.asarray(data["pi_losses"])
    temperature_losses = np.asarray(data["temperature_loss"])

# %%
fig=plt.figure(figsize=(6,3.8))
plt.plot(running_mean(rewards,10))

# %%
checkpoint = f"./SAC_{env_name}-e{int(max_episodes/save_interval)*save_interval}-t{train_iter}-s{random_seed}.pth"
env = gym.make(env_name, render_mode="human")
agent = sac.SAC_Agent(env.observation_space, env.action_space)
agent.eval()
#TODO implement agent working in environment
observation, info = env.reset(seed=42)
for _ in range(1000):
   action = agent.act(observation)
   observation, reward, terminated, truncated, info = env.step(action)

   if terminated or truncated:
      observation, info = env.reset()
# Out:
# Exception ignored in: <function WindowViewer.__del__ at 0x000001C026E488B0>
# Traceback (most recent call last):
#   File "d:\Conda\envs\rl\lib\site-packages\gymnasium\envs\mujoco\mujoco_rendering.py", line 335, in __del__
#     self.free()
#   File "d:\Conda\envs\rl\lib\site-packages\gymnasium\envs\mujoco\mujoco_rendering.py", line 330, in free
#     glfw.destroy_window(self.window)
#   File "d:\Conda\envs\rl\lib\site-packages\glfw\__init__.py", line 1279, in destroy_window
#     window_addr = ctypes.cast(ctypes.pointer(window),
# TypeError: _type_ must have storage info
# Agent now in evaluation Mode

# %%
env.close()

# %% [markdown]
# ## Lunar Lander

# %%
#env_name = "Pendulum-v1"
env_name = "LunarLander-v2"
log_interval = 20         # print avg reward in the interval
max_episodes = 500 # max training episodes
max_timesteps = 2000         # max timesteps in one episode
save_interval = 500
train_iter = 32      # update networks for given batched after every episode
random_seed = 42

# %%
run_sac_agent_in_environment(env_name=env_name,log_interval=log_interval,save_interval=save_interval,max_episodes=max_episodes,max_timesteps=max_timesteps,train_iter=train_iter,random_seed=random_seed)

# %%
with open(f"./results/SAC_{env_name}-s{random_seed}-e{int(max_episodes/save_interval)*save_interval}-stat.pkl", 'rb') as f:
    data = pickle.load(f)
    rewards = np.asarray(data["rewards"])
    q_losses =  np.asarray(data["q_losses"])
    pi_losses  = np.asarray(data["pi_losses"])
    temperature_losses = np.asarray(data["temperature_loss"])

# %%
fig=plt.figure(figsize=(6,3.8))
plt.plot(running_mean(q_losses,10),label=f"Q loss")
plt.plot(running_mean(pi_losses,10),label=f"Pi loss")
plt.plot(running_mean(temperature_losses,10),label=f"Temp loss")
plt.legend()

# %%
fig=plt.figure(figsize=(6,3.8))
plt.plot(running_mean(rewards,10),label=f"rewards")
plt.legend()

# %%
env = gym.make(env_name, render_mode="human")
agent = sac.SAC_Agent(env.observation_space, env.action_space)
agent.eval()
#TODO implement agent working in environment
observation, info = env.reset(seed=42)
for _ in range(1000):
   action = agent.act(observation)
   observation, reward, terminated, truncated, info = env.step(action)

   if terminated or truncated:
      observation, info = env.reset()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedSpace                          Traceback (most recent call last)
# Cell In[30], line 2
#       1 env = gym.make(env_name, render_mode="human")
# ----> 2 agent = sac.SAC_Agent(env.observation_space, env.action_space)
#       3 agent.eval()
#       4 #TODO implement agent working in environment
#
# File c:\Users\Moritz Christ\Documents\Uni\23Wintersemester\RL\Project\RL\RL_Agent\SAC\sac.py:24, in SAC_Agent.__init__(self, observation_space, action_space, **userconfig)
#      22 def __init__(self,observation_space,action_space, **userconfig):
# ---> 24     super().__init__(observation_space,action_space,**userconfig)
#      26     self._config = {
#      27         "start_steps":10,
#      28         "discount": 0.99,
#    (...)
#      45         "use_smooth_L1":False,
#      46         }
#      47     self.memory = mem.Memory(max_size=self._config["buffer_size"])
#
# File c:\Users\Moritz Christ\Documents\Uni\23Wintersemester\RL\Project\RL\RL_Agent\SAC\Agent.py:22, in agent.__init__(self, observation_space, action_space, **userconfig)
#      19     raise UnsupportedSpace('Observation space {} incompatible ' \
#      20                            'with {}. (Require: Box)'.format(observation_space, self))
#      21 if not isinstance(action_space, spaces.box.Box):
# ---> 22     raise UnsupportedSpace('Action space {} incompatible with {}.' \
#      23                            ' (Require Box)'.format(action_space, self))
#      24 self._config= {}
#      25 self.memory = None
#
# UnsupportedSpace: Action space Discrete(4) incompatible with <sac.SAC_Agent object at 0x000001C0F2BB8850>. (Require Box)

# %%
env.close()

# %% [markdown]
# ### Mountain Car Continuous

# %%
env_name = "MountainCarContinuous-v0"
log_interval = 20         # print avg reward in the interval
max_episodes = 500 # max training episodes
max_timesteps = 2000         # max timesteps in one episode
save_interval = 500
train_iter = 32      # update networks for given batched after every episode
random_seed = 42

# %%
run_sac_agent_in_environment(env_name=env_name,log_interval=log_interval,save_interval=save_interval,max_episodes=max_episodes,max_timesteps=max_timesteps,train_iter=train_iter,random_seed=random_seed)
# Out:
# Episode 20 	 avg length: 998 	 reward: -33.147519518884984
# Episode 40 	 avg length: 994 	 reward: -27.13377938931881
# Episode 60 	 avg length: 998 	 reward: -30.55710534574218
# Episode 80 	 avg length: 998 	 reward: -26.888839860605497
# Episode 100 	 avg length: 998 	 reward: -21.269751748009032
# Episode 120 	 avg length: 998 	 reward: -15.550166540288028
# Episode 140 	 avg length: 998 	 reward: -10.984499256470787
# Episode 160 	 avg length: 998 	 reward: -8.178348900530604
# Episode 180 	 avg length: 998 	 reward: -6.98959107974264
# Episode 200 	 avg length: 998 	 reward: -6.345959590000421
# Episode 220 	 avg length: 998 	 reward: -5.914647748590815
# Episode 240 	 avg length: 998 	 reward: -5.975790943922293
# Episode 260 	 avg length: 998 	 reward: -6.069305462784406
# Episode 280 	 avg length: 998 	 reward: -5.952483282016269
# Episode 300 	 avg length: 998 	 reward: -6.196966294209286
# Episode 320 	 avg length: 998 	 reward: -6.2090386181203385
# Episode 340 	 avg length: 998 	 reward: -6.501881624562747
# Episode 360 	 avg length: 998 	 reward: -6.471654960910082
# Episode 380 	 avg length: 998 	 reward: -6.289949216145011
# Episode 400 	 avg length: 998 	 reward: -6.805086488125111
# Episode 420 	 avg length: 998 	 reward: -6.893164698428907
# Episode 440 	 avg length: 998 	 reward: -6.782681751953445
# Episode 460 	 avg length: 998 	 reward: -6.764430792171565
# Episode 480 	 avg length: 998 	 reward: -6.542527493402419
# ########### Save checkpoint ################
# Episode 500 	 avg length: 998 	 reward: -6.209390634150691

# %%
with open(f"./results/SAC_{env_name}-s{random_seed}-e{int(max_episodes/save_interval)*save_interval}-stat.pkl", 'rb') as f:
    data = pickle.load(f)
    rewards = np.asarray(data["rewards"])
    q_losses =  np.asarray(data["q_losses"])
    pi_losses  = np.asarray(data["pi_losses"])
    temperature_losses = np.asarray(data["temperature_loss"])

# %%
fig=plt.figure(figsize=(6,3.8))
plt.plot(running_mean(q_losses,10),label=f"Q loss")
plt.plot(running_mean(pi_losses,10),label=f"Pi loss")
plt.plot(running_mean(temperature_losses,10),label=f"Temp loss")
plt.legend()

# %%
fig=plt.figure(figsize=(6,3.8))
plt.plot(running_mean(rewards,10),label=f"rewards")
plt.legend()

# %%
checkpoint = f"./results/SAC_{env_name}-e{int(max_episodes/save_interval)*save_interval}-t{train_iter}-s{random_seed}.pth"
env = gym.make(env_name, render_mode="human")
agent = sac.SAC_Agent(env.observation_space, env.action_space)
agent.load_network_states(torch.load(checkpoint))
agent.eval()
#TODO implement agent working in environment
observation, info = env.reset(seed=42)
for _ in range(1000):
   action = agent.act(observation)
   observation, reward, terminated, truncated, info = env.step(action)

   if terminated or truncated:
      observation, info = env.reset()
# Out:
# Agent now in evaluation Mode

# %%
env.close()
